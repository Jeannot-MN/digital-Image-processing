# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from skimage import data

img = data.page()
print(img.shape)

bin_img = np.zeros(img.shape).astype('uint8')

bin_img[img <80] = 0
bin_img[img >=80] = 1

plt.imshow(bin_img, cmap=cm.gray)
plt.show()
# Out:
# (191, 384)
