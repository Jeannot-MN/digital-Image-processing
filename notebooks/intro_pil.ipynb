# %%
from PIL import Image

img = Image.open("assets/images/profile.jpg")
# img.show()
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=749x707>

# %%
new_img = Image.open("assets/images/profile.jpg").convert('L')
display(new_img)
# Out:
# <PIL.Image.Image image mode=L size=749x707>

# %%
new_img.size
# Out:
# (749, 707)

# %%
img = Image.open("assets/images/profile.jpg")
resized_img = img.resize((120,120))
display(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=120x120>

# %%
cropped_img = img.crop((0,0,100,100))
display(cropped_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
rotate_img = img.rotate(30)
display(rotate_img)
# Out:
# <PIL.Image.Image image mode=RGB size=749x707>

# %%
import matplotlib.pyplot as plt

img = plt.imread('assets/images/profile.jpg')
print(img.shape)
print(img.dtype)

plt.imshow(img)
plt.show()
# Out:
# (707, 749, 3)
# uint8
